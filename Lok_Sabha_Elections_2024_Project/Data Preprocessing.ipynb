# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **CANDIDATES**

# %%
candidates_df = pd.read_csv('source_files/candidates_with_phase.csv')

# %%
candidates_df
# Out:
#                           State  Constituency_No               Constituency  \
# 0     Andaman & Nicobar Islands                1  Andaman & Nicobar Islands
# 1     Andaman & Nicobar Islands                1  Andaman & Nicobar Islands
# 2     Andaman & Nicobar Islands                1  Andaman & Nicobar Islands
# 3     Andaman & Nicobar Islands                1  Andaman & Nicobar Islands
# 4     Andaman & Nicobar Islands                1  Andaman & Nicobar Islands
# ...                         ...              ...                        ...
# 8436                West Bengal               42                    Birbhum
# 8437                West Bengal               42                    Birbhum
# 8438                West Bengal               42                    Birbhum
# 8439                West Bengal               42                    Birbhum
# 8440                West Bengal               42                    Birbhum
#
# ...

# %%
candidates_df['State'] = candidates_df['State'].apply(lambda x:x.upper())
candidates_df['Constituency'] = candidates_df['Constituency'].apply(lambda x:x.upper())
candidates_df['Party'] = candidates_df['Party'].apply(lambda x:x.upper())
candidates_df['Candidate Name'] = candidates_df['Candidate Name'].apply(lambda x:x.upper())
candidates_df['Gender'] = candidates_df['Gender'].apply(lambda x:x.upper())

# %%
candidates_df
# Out:
#                           State  Constituency_No               Constituency  \
# 0     ANDAMAN & NICOBAR ISLANDS                1  ANDAMAN & NICOBAR ISLANDS
# 1     ANDAMAN & NICOBAR ISLANDS                1  ANDAMAN & NICOBAR ISLANDS
# 2     ANDAMAN & NICOBAR ISLANDS                1  ANDAMAN & NICOBAR ISLANDS
# 3     ANDAMAN & NICOBAR ISLANDS                1  ANDAMAN & NICOBAR ISLANDS
# 4     ANDAMAN & NICOBAR ISLANDS                1  ANDAMAN & NICOBAR ISLANDS
# ...                         ...              ...                        ...
# 8436                WEST BENGAL               42                    BIRBHUM
# 8437                WEST BENGAL               42                    BIRBHUM
# 8438                WEST BENGAL               42                    BIRBHUM
# 8439                WEST BENGAL               42                    BIRBHUM
# 8440                WEST BENGAL               42                    BIRBHUM
#
# ...

# %%
candidates_df.to_csv('datasets/Candidates.csv',index=False)

# %% [markdown]
# **RESULTS**

# %%
results_df = pd.read_csv('source_files/election_results.csv')

# %%
results_df.rename(columns={'PC Name': 'Constituency'},inplace=True)

# %%
results_df.rename(columns={'PC N0': 'ConstituencyKey'},inplace=True)

# %%
results_df
# Out:
#                   State  PC No Constituency  Sl no                Candidate  \
# 0        Andhra Pradesh      1   Araku (ST)      1       GUMMA THANUJA RANI
# 1        Andhra Pradesh      1   Araku (ST)      2        KOTHAPALLI GEETHA
# 2        Andhra Pradesh      1   Araku (ST)      3  APPALANARASA PACHIPENTA
# 3        Andhra Pradesh      1   Araku (ST)      4   AVASHYA LAHARI . VARAM
# 4        Andhra Pradesh      1   Araku (ST)      5    SAMAREDDY BALAKRISHNA
# ...                 ...    ...          ...    ...                      ...
# 8897  Jammu and Kashmir      5        JAMMU     23                     NOTA
# 8898             Ladakh      1       Ladakh      1           MOHMAD HANEEFA
# 8899             Ladakh      1       Ladakh      2          TSERING NAMGYAL
# 8900             Ladakh      1       Ladakh      3            TASHI GYALSON
# 8901             Ladakh      1       Ladakh      4                     NOTA
#
# ...

# %%
results_df['State'] = results_df['State'].apply(lambda x:x.upper())
results_df['Constituency'] = results_df['Constituency'].apply(lambda x:x.upper())
results_df['Party'] = results_df['Party'].apply(lambda x:x.upper())
results_df['Candidate'] = results_df['Candidate'].apply(lambda x:x.upper())

# %%
results_df
# Out:
#                   State  PC No Constituency  Sl no                Candidate  \
# 0        ANDHRA PRADESH      1   ARAKU (ST)      1       GUMMA THANUJA RANI
# 1        ANDHRA PRADESH      1   ARAKU (ST)      2        KOTHAPALLI GEETHA
# 2        ANDHRA PRADESH      1   ARAKU (ST)      3  APPALANARASA PACHIPENTA
# 3        ANDHRA PRADESH      1   ARAKU (ST)      4   AVASHYA LAHARI . VARAM
# 4        ANDHRA PRADESH      1   ARAKU (ST)      5    SAMAREDDY BALAKRISHNA
# ...                 ...    ...          ...    ...                      ...
# 8897  JAMMU AND KASHMIR      5        JAMMU     23                     NOTA
# 8898             LADAKH      1       LADAKH      1           MOHMAD HANEEFA
# 8899             LADAKH      1       LADAKH      2          TSERING NAMGYAL
# 8900             LADAKH      1       LADAKH      3            TASHI GYALSON
# 8901             LADAKH      1       LADAKH      4                     NOTA
#
# ...

# %%
results_df["EVM Votes"].replace("-",0,inplace=True)
results_df["Postal Votes"].replace("-",0,inplace=True)
results_df["Total Votes"].replace("-",0,inplace=True)
results_df["Vote Share"].replace("-",0,inplace=True)
results_df[results_df["EVM Votes"]==0]
# Out:
# C:\Users\anubh\AppData\Local\Temp\ipykernel_20732\4097850311.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   results_df["EVM Votes"].replace("-",0,inplace=True)
# C:\Users\anubh\AppData\Local\Temp\ipykernel_20732\4097850311.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
results_df.to_csv('datasets/Results.csv',index = False)

# %% [markdown]
# **WINNERS**

# %%
winners_df = pd.read_csv('source_files/election_winners.csv')

# %%
winners_df
# Out:
#          Constituency  Const. No.         Leading Candidate  \
# 0               AJMER          13       BHAGIRATH CHOUDHARY
# 1               ALWAR           8           BHUPENDER YADAV
# 2              AMBALA           1            VARUN CHAUDHRY
# 3    ANANTNAG-RAJOURI           3          MIAN ALTAF AHMAD
# 4           ARAKKONAM           7         S JAGATHRATCHAKAN
# ..                ...         ...                       ...
# 538            Wardha           8       AMAR SHARADRAO KALE
# 539           Wayanad           4              RAHUL GANDHI
# 540        West Delhi           6        KAMALJEET SEHRAWAT
# 541  Yavatmal- Washim          14  SANJAY UTTAMRAO DESHMUKH
# 542         Zahirabad           5      SURESH KUMAR SHETKAR
#
#                                         Leading Party  \
# 0                              Bharatiya Janata Party
# 1                              Bharatiya Janata Party
# 2                            Indian National Congress
# ...

# %%
winners_df[winners_df.Status!='Result Declared']
# Out:
#     Constituency  Const. No.               Leading Candidate  \
# 493        Surat          24  MUKESHKUMAR CHANDRAKAANT DALAL
#
#               Leading Party Trailing Candidate Trailing Party Margin  \
# 493  Bharatiya Janata Party                NaN            NaN      -
#
#           Status
# 493  Uncontested

# %%
winners_df["Trailing Candidate"].fillna("", inplace=True)
winners_df["Trailing Party"].fillna("", inplace=True)
winners_df["Margin"].replace("-",0,inplace=True)
winners_df[winners_df.Constituency == "Surat"]
# Out:
# C:\Users\anubh\AppData\Local\Temp\ipykernel_20732\4224305843.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   winners_df["Trailing Candidate"].fillna("", inplace=True)
# C:\Users\anubh\AppData\Local\Temp\ipykernel_20732\4224305843.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
winners_df['Constituency'] = winners_df['Constituency'].apply(lambda x:x.upper())
winners_df['Leading Candidate'] = winners_df['Leading Candidate'].apply(lambda x:x.upper())
winners_df['Leading Party'] = winners_df['Leading Party'].apply(lambda x:x.upper())
winners_df['Trailing Candidate'] = winners_df['Trailing Candidate'].apply(lambda x:x.upper())
winners_df['Trailing Party'] = winners_df['Trailing Party'].apply(lambda x:x.upper())

# %%
winners_df
# Out:
#          Constituency  Const. No.         Leading Candidate  \
# 0               AJMER          13       BHAGIRATH CHOUDHARY
# 1               ALWAR           8           BHUPENDER YADAV
# 2              AMBALA           1            VARUN CHAUDHRY
# 3    ANANTNAG-RAJOURI           3          MIAN ALTAF AHMAD
# 4           ARAKKONAM           7         S JAGATHRATCHAKAN
# ..                ...         ...                       ...
# 538            WARDHA           8       AMAR SHARADRAO KALE
# 539           WAYANAD           4              RAHUL GANDHI
# 540        WEST DELHI           6        KAMALJEET SEHRAWAT
# 541  YAVATMAL- WASHIM          14  SANJAY UTTAMRAO DESHMUKH
# 542         ZAHIRABAD           5      SURESH KUMAR SHETKAR
#
#                                         Leading Party  \
# 0                              BHARATIYA JANATA PARTY
# 1                              BHARATIYA JANATA PARTY
# 2                            INDIAN NATIONAL CONGRESS
# ...

# %%
winners_df.rename(columns = {'Const. No.':'ConstituencyKey'},inplace = True)

# %%
winners_df
# Out:
#          Constituency  ConstituencyKey         Leading Candidate  \
# 0               AJMER               13       BHAGIRATH CHOUDHARY
# 1               ALWAR                8           BHUPENDER YADAV
# 2              AMBALA                1            VARUN CHAUDHRY
# 3    ANANTNAG-RAJOURI                3          MIAN ALTAF AHMAD
# 4           ARAKKONAM                7         S JAGATHRATCHAKAN
# ..                ...              ...                       ...
# 538            WARDHA                8       AMAR SHARADRAO KALE
# 539           WAYANAD                4              RAHUL GANDHI
# 540        WEST DELHI                6        KAMALJEET SEHRAWAT
# 541  YAVATMAL- WASHIM               14  SANJAY UTTAMRAO DESHMUKH
# 542         ZAHIRABAD                5      SURESH KUMAR SHETKAR
#
#                                         Leading Party  \
# 0                              BHARATIYA JANATA PARTY
# 1                              BHARATIYA JANATA PARTY
# ...

# %%
winners_df.to_csv('datasets/Winners.csv',index=False)

# %% [markdown]
# **TURNOUT**

# %%
turnout_df = pd.read_csv('source_files/voter_turnout.csv')

# %%
turnout_df
# Out:
#       ID                      State                    PC_Name  \
# 0      1  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 1      2          Arunachal Pradesh             Arunachal East
# 2      3          Arunachal Pradesh             Arunachal West
# 3      4                      Assam                  Dibrugarh
# 4      5                      Assam                     Jorhat
# ..   ...                        ...                        ...
# 481  482                West Bengal                   Jhargram
# 482  483                West Bengal                     Kanthi
# 483  484                West Bengal                  Medinipur
# 484  485                West Bengal                    Purulia
# 485  486                West Bengal                     Tamluk
#
#      Total Electors  Polled (%)  Total Votes  Phase
# 0            315148       64.10       202018      1
# 1            375310       83.31       312658      1
# ...

# %%
turnout_df.rename(columns={'PC_Name':'Constituency'},inplace=True)

# %%
turnout_df['State'] = turnout_df['State'].apply(lambda x:x.upper())
turnout_df['Constituency'] = turnout_df['Constituency'].apply(lambda x:x.upper())

# %%
turnout_df
# Out:
#       ID                      State               Constituency  \
# 0      1  ANDAMAN & NICOBAR ISLANDS  ANDAMAN & NICOBAR ISLANDS
# 1      2          ARUNACHAL PRADESH             ARUNACHAL EAST
# 2      3          ARUNACHAL PRADESH             ARUNACHAL WEST
# 3      4                      ASSAM                  DIBRUGARH
# 4      5                      ASSAM                     JORHAT
# ..   ...                        ...                        ...
# 481  482                WEST BENGAL                   JHARGRAM
# 482  483                WEST BENGAL                     KANTHI
# 483  484                WEST BENGAL                  MEDINIPUR
# 484  485                WEST BENGAL                    PURULIA
# 485  486                WEST BENGAL                     TAMLUK
#
#      Total Electors  Polled (%)  Total Votes  Phase
# 0            315148       64.10       202018      1
# 1            375310       83.31       312658      1
# ...

# %%
turnout_df.to_csv('datasets/Turnout.csv',index = False)
